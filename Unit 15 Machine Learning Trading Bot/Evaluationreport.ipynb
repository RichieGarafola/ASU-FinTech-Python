# %% [markdown]
# # **Machine Learning Trading Bot**
# ## Evaluation Report
#
# ---
#
# ### *Logistic Regression*
# ---
#
#
#
#               precision    recall  f1-score   support
#
#         -1.0       0.44      0.33      0.38      1804
#          1.0       0.56      0.66      0.61      2288
#
#     accuracy                           0.52      4092
#    macro avg       0.50      0.50      0.49      4092
# weighted avg       0.51      0.52      0.51      4092
#
#
# ---
#
# Below you will see a cumulative return plot that shows the actual returns vs. the strategy returns. This will serve as a baseline against which to compare the effects of tuning the trading algorithm.
#
#
# ![logistic_regression_plot.png](data:image/png;base64,...)
#
#
#
#
#
#
#
# ---
#
# Now you can see the cumulative product of the actual returns vs. the strategy returns for the updated trading algorithm.
#
# ![ model_compare_logistic_regression_plot.png](data:image/png;base64,...)
#
#
#
#
#
# ---
#
#
# **Question:**
# Did this new model perform better or worse than the provided baseline model? Did this new model perform better or worse than your tuned trading algorithm
#
#
#
#
# **Answer:**
# The Baseline SVM Strategy is tightly correlated to the Actual Returns, it is marginally higher.
# The Logistic Regression model remained tightly correlated to the actual returns until late 2017 where it started to inverserly correlate leading into 2019. By 2019 Logistic Regression model started to grow wings and really outperform both the baseline strategy and actual returns. Midway through 2020 however one bad day compounded into another and up until current the Logistic Regression Strategy is now inversly correlated to both the baseline and actual returns. Despite periods of outperformance, the end justifys the means, therefore the new model as of current performs worse that the SVM baseline strategy.
#
# ---
#
#
#
#
#
# ### *Decision Tree Classifier*
#
# ---
#
#
#               precision    recall  f1-score   support
#
#         -1.0       0.43      0.04      0.07      1804
#          1.0       0.56      0.96      0.71      2288
#
#     accuracy                           0.55      4092
#    macro avg       0.49      0.50      0.39      4092
# weighted avg       0.50      0.55      0.43      4092
#
#
# ---
#
# Below you will see a cumulative return plot that shows the actual returns vs. the strategy returns. This will serve as a baseline against which to compare the effects of tuning the trading algorithm.
#
#
# ![decision_tree_plot.png](data:image/png;base64,...)
#
#
#
#
#
#
#
# ---
#
# Now you can see the cumulative product of the actual returns vs. the strategy returns for the updated trading algorithm Decision Tree Classifier.
#
# ![ decisiontree_model_compare.png](data:image/png;base64,...)
#
#
#
#
#
# ---
#
#
# **Question:**
# Did this new model perform better or worse than the provided baseline model? Did this new model perform better or worse than your tuned trading algorithm
#
#
#
#
# **Answer:**
# The Baseline SVM Strategy is tightly correlated to the Actual Returns, infact it is marginally higher. The Decision Tree Classifier model however from start to current remained negative. For a majority of the time there is an inversere correlation but overall the trend is overall down. The new model performs significantly worse that the SVM baseline strategy.
#
# ---
#
#
# ### *AdaBoost*
#
# ---
#
#
#               precision    recall  f1-score   support
#
#         -1.0       0.43      0.04      0.07      1804
#          1.0       0.56      0.96      0.71      2288
#
#     accuracy                           0.55      4092
#    macro avg       0.49      0.50      0.39      4092
# weighted avg       0.50      0.55      0.43      4092
#
#
#
# Below you will see a cumulative return plot that shows the actual returns vs. the strategy returns. This will serve as a baseline against which to compare the effects of tuning the trading algorithm.
#
# ![ada_boost_plot.png](data:image/png;base64,...)
#
#
#
#
#
#
#
#
# ---
#
# Now you can see the cumulative product of the actual returns vs. the strategy returns for the updated trading algorithm AdaBoost.
#
#
#
# ![ AdaBoost_model_compare.png](data:image/png;base64,...)
#
#
#
# ---
#
#
# **Question:**
# Did this new model perform better or worse than the provided baseline model? Did this new model perform better or worse than your tuned trading algorithm
#
#
#
#
# **Answer:**
# The Baseline SVM Strategy is tightly correlated to the Actual Returns, it actually performs marginally better. The AdaBoost model is also tightly correlated. It had a period from 2019-2020 where its performance was inversely correlated to that of the baseline SVM stratefy but early 2020 it tuened around and has been outperforming both the actual returns and SVM strategy ever since.
